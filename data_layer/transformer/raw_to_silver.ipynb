# %%
# !pip install -r ../../requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from -r ../../requirements.txt (line 1)) (2.3.1)
# Requirement already satisfied: numpy in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from -r ../../requirements.txt (line 2)) (2.3.2)
# Requirement already satisfied: seaborn in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from -r ../../requirements.txt (line 3)) (0.13.2)
# Requirement already satisfied: matplotlib in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from -r ../../requirements.txt (line 4)) (3.10.5)
# Requirement already satisfied: plotly in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from -r ../../requirements.txt (line 5)) (6.3.1)
# Requirement already satisfied: kagglehub in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from -r ../../requirements.txt (line 6)) (0.3.13)
# Collecting ipywidgets (from -r ../../requirements.txt (line 7))
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: sqlalchemy in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from -r ../../requirements.txt (line 8)) (2.0.43)
# Requirement already satisfied: psycopg2-binary in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from -r ../../requirements.txt (line 9)) (2.9.10)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cliente\appdata\roaming\python\python313\site-packages (from pandas->-r ../../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r ../../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from pandas->-r ../../requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ../../requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ../../requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ../../requirements.txt (line 4)) (4.59.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ../../requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ../../requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ../../requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->-r ../../requirements.txt (line 4)) (3.2.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from plotly->-r ../../requirements.txt (line 5)) (2.7.0)
# Requirement already satisfied: pyyaml in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from kagglehub->-r ../../requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: requests in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from kagglehub->-r ../../requirements.txt (line 6)) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from kagglehub->-r ../../requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\cliente\appdata\roaming\python\python313\site-packages (from ipywidgets->-r ../../requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\cliente\appdata\roaming\python\python313\site-packages (from ipywidgets->-r ../../requirements.txt (line 7)) (9.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\cliente\appdata\roaming\python\python313\site-packages (from ipywidgets->-r ../../requirements.txt (line 7)) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->-r ../../requirements.txt (line 7))
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->-r ../../requirements.txt (line 7))
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: greenlet>=1 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy->-r ../../requirements.txt (line 8)) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from sqlalchemy->-r ../../requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: colorama in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (0.4.6)
# Requirement already satisfied: decorator in c:\users\cliente\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\cliente\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\cliente\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\cliente\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\cliente\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\cliente\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: six>=1.5 in c:\users\cliente\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas->-r ../../requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub->-r ../../requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub->-r ../../requirements.txt (line 6)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub->-r ../../requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cliente\appdata\local\programs\python\python313\lib\site-packages (from requests->kagglehub->-r ../../requirements.txt (line 6)) (2025.10.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\cliente\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\cliente\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\cliente\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\cliente\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\cliente\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets->-r ../../requirements.txt (line 7)) (0.2.3)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 914.9/914.9 kB 9.8 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 10.6 MB/s eta 0:00:00
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import re
import pathlib
import shutil
import kagglehub
import os
import psycopg2
from sqlalchemy import create_engine,text

# %%
project_root = pathlib.Path(os.getcwd()).resolve().parents[0]

caminho_bases = project_root / "raw" / "csv_collected"
caminho_bases.mkdir(parents=True, exist_ok=True)

destino = caminho_bases

print(f"Usando pasta destino:\n{destino}\n")

arquivos_existentes = list(destino.glob("*"))
if arquivos_existentes:
    print("Arquivos já existem. Pulando download.\n")
    raise SystemExit()

print("Nenhum arquivo encontrado. Iniciando download...\n")

raw_download = kagglehub.dataset_download("allanbruno/airbnb-rio-de-janeiro")

if isinstance(raw_download, str):
    path = pathlib.Path(raw_download)
elif isinstance(raw_download, list):
    path = pathlib.Path(raw_download[0])
else:
    path = pathlib.Path(str(raw_download))

print(f"Dataset baixado em: {path}\n")

for arquivo in path.iterdir():
    if "2019" not in arquivo.name:
        continue

    destino_arquivo = destino / arquivo.name
    shutil.copy2(arquivo, destino_arquivo)
    print(f"Copiado (2019): {arquivo.name}")

print("\nArquivos 2019 copiados para data_layer/raw/csv_collected.")
# Out:
# Usando pasta destino:
# C:\Users\Cliente\Documents\FGA2\Bancos2\Airbnb_2019_Rio\data_layer\raw\csv_collected
#
# Nenhum arquivo encontrado. Iniciando download...
#
# Dataset baixado em: C:\Users\Cliente\.cache\kagglehub\datasets\allanbruno\airbnb-rio-de-janeiro\versions\4
#
# Copiado (2019): abril2019.csv
# Copiado (2019): agosto2019.csv
# Copiado (2019): dezembro2019.csv
# Copiado (2019): fevereiro2019.csv
# Copiado (2019): janeiro2019.csv
# Copiado (2019): julho2019.csv
# Copiado (2019): junho2019.csv
# Copiado (2019): maio2019.csv
# Copiado (2019): maro2019.csv
# Copiado (2019): novembro2019.csv
# Copiado (2019): outubro2019.csv
# Copiado (2019): setembro2019.csv
#
# Arquivos 2019 copiados para data_layer/raw/csv_collected.

# %%
if "__file__" in globals():
    project_root = pathlib.Path(__file__).resolve().parents[1]
else:
    project_root = pathlib.Path(os.getcwd()).resolve().parents[0]

caminho_bases = project_root / "raw" / "csv_collected"

print("Lendo arquivos de:", caminho_bases)

meses = {
    'jan': 1, 'fev': 2, 'mar': 3, 'abr': 4, 'mai': 5, 'jun': 6,
    'jul': 7, 'ago': 8, 'set': 9, 'out': 10, 'nov': 11, 'dez': 12
}

base_airbnb = pd.DataFrame()

for arquivo in caminho_bases.iterdir():
    if arquivo.suffix != '.csv': 
        continue

    nome_mes = arquivo.name[:3].lower()  
    if nome_mes not in meses:
        print(f"Arquivo ignorado: {arquivo.name}")
        continue

    mes = meses[nome_mes]
    ano = int(arquivo.name[-8:].replace('.csv', ''))

    if ano != 2019:
        continue

    df = pd.read_csv(arquivo, low_memory=False)
    df['ano'] = ano
    df['mes'] = mes
    base_airbnb = pd.concat([base_airbnb, df], ignore_index=True)

display(base_airbnb)
# Out:
# Lendo arquivos de: C:\Users\Cliente\Documents\FGA2\Bancos2\Airbnb_2019_Rio\data_layer\raw\csv_collected
#               id                            listing_url       scrape_id  \
# 0          17878     https://www.airbnb.com/rooms/17878  20190416181629
# 1          25026     https://www.airbnb.com/rooms/25026  20190416181629
# 2          31560     https://www.airbnb.com/rooms/31560  20190416181629
# 3          35636     https://www.airbnb.com/rooms/35636  20190416181629
# 4          35764     https://www.airbnb.com/rooms/35764  20190416181629
# ...          ...                                    ...             ...
# 422031  38844730  https://www.airbnb.com/rooms/38844730  20190923212307
# 422032  38846408  https://www.airbnb.com/rooms/38846408  20190923212307
# 422033  38846703  https://www.airbnb.com/rooms/38846703  20190923212307
# 422034  38847050  https://www.airbnb.com/rooms/38847050  20190923212307
# 422035  38847655  https://www.airbnb.com/rooms/38847655  20190923212307
#
#        last_scraped                                          name  \
# 0        2019-04-16             Very Nice 2Br - Copacabana - WiFi
# 1        2019-04-16     Beautiful Modern Decorated Studio in Copa
# 2        2019-04-17              NICE & COZY 1BDR - IPANEMA BEACH
# 3        2019-04-17              Cosy flat close to Ipanema beach
# 4        2019-04-16                 COPACABANA SEA BREEZE  -  RIO
# ...             ...                                           ...
# 422031   2019-09-24             TRANSAMERICA BARRA DA TIJUCA R IV
# 422032   2019-09-24                      Alugo para o Rock in Rio
# 422033   2019-09-24  Apt COMPLETO em COPACABANA c/TOTAL SEGURANÇA
# 422034   2019-09-24                     Cobertura Cinematografica
# 422035   2019-09-24     Quarto em cobertura em frente à praia III
#
#                                                   summary  \
# 0       Please note that special rates apply for New Y...
# 1       Our apartment is a little gem, everyone loves ...
# 2       This nice and clean 1 bedroom apartment is loc...
# 3       This cosy apartment  is just a few steps away ...
# 4       Our newly renovated studio is located in the b...
# ...                                                   ...
# 422031  Em estilo contemporâneo, o Transamerica Prime ...
# 422032  Confortável apartamento, 2 quartos , sendo 1 s...
# 422033  Apartamento quarto e sala COMPLETO para curtas...
# 422034                               Cobertura alto nivel
# 422035  Quarto em cobertura quadriplex com vista lindí...
#
#                                                     space  \
# 0       - large balcony which looks out on pedestrian ...
# 1       This newly renovated studio (last renovations ...
# 2       This nice and clean 1 bedroom apartment is loc...
# 3       The location is extremely convenient, safe and...
# 4       FEEL LIKE YOUR HOME LIVING AS "CARIOCA" LOCAL ...
# ...                                                   ...
# 422031                                                NaN
# 422032  O apartamento estará com mobília completa disp...
# 422033  Espaço ideal para até 5 pessoas. Cama de casal...
# 422034                                                NaN
# 422035                                                NaN
#
#                                               description experiences_offered  \
# 0       Please note that special rates apply for New Y...                none
# 1       Our apartment is a little gem, everyone loves ...                none
# 2       This nice and clean 1 bedroom apartment is loc...                none
# 3       This cosy apartment  is just a few steps away ...                none
# 4       Our newly renovated studio is located in the b...                none
# ...                                                   ...                 ...
# 422031  Em estilo contemporâneo, o Transamerica Prime ...                none
# 422032  Confortável apartamento, 2 quartos , sendo 1 s...                none
# 422033  Apartamento quarto e sala COMPLETO para curtas...                none
# 422034                               Cobertura alto nivel                none
# 422035  Quarto em cobertura quadriplex com vista lindí...                none
#
#                                     neighborhood_overview  ...  \
# 0       This is the best spot in Rio. Everything happe...  ...
# 1       Copacabana is a lively neighborhood and the ap...  ...
# 2       Die Nachbarschaft von Ipanema ist super lebend...  ...
# 3       The  apartment street is very quiet and safe ....  ...
# 4       Our guests will experience living with a local...  ...
# ...                                                   ...  ...
# 422031                                                NaN  ...
# 422032  Muito próximo ao Parque Olímpico, local do eve...  ...
# 422033                                                NaN  ...
# 422034                                                NaN  ...
# 422035                                                NaN  ...
#
#                 cancellation_policy require_guest_profile_picture  \
# 0       strict_14_with_grace_period                             f
# 1       strict_14_with_grace_period                             t
# 2       strict_14_with_grace_period                             f
# 3       strict_14_with_grace_period                             t
# 4       strict_14_with_grace_period                             f
# ...                             ...                           ...
# 422031                     flexible                             f
# 422032                     flexible                             f
# 422033  strict_14_with_grace_period                             f
# 422034  strict_14_with_grace_period                             f
# 422035  strict_14_with_grace_period                             f
#
#        require_guest_phone_verification calculated_host_listings_count  \
# 0                                     f                              1
# 1                                     t                              3
# 2                                     f                              1
# 3                                     t                              1
# 4                                     t                              1
# ...                                 ...                            ...
# 422031                                f                             15
# 422032                                f                              1
# 422033                                f                             29
# 422034                                f                              1
# 422035                                f                              4
#
#        calculated_host_listings_count_entire_homes  \
# 0                                                1
# 1                                                3
# 2                                                1
# 3                                                1
# 4                                                1
# ...                                            ...
# 422031                                          15
# 422032                                           1
# 422033                                          23
# 422034                                           1
# 422035                                           0
#
#         calculated_host_listings_count_private_rooms  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
# ...                                              ...
# 422031                                             0
# 422032                                             0
# 422033                                             6
# 422034                                             0
# 422035                                             4
#
#         calculated_host_listings_count_shared_rooms reviews_per_month   ano  \
# 0                                                 0              2.10  2019
# 1                                                 0              2.12  2019
# 2                                                 0              2.33  2019
# 3                                                 0              2.20  2019
# 4                                                 0              2.80  2019
# ...                                             ...               ...   ...
# 422031                                            0               NaN  2019
# 422032                                            0               NaN  2019
# 422033                                            0               NaN  2019
# 422034                                            0               NaN  2019
# 422035                                            0               NaN  2019
#
#         mes
# 0         4
# 1         4
# 2         4
# 3         4
# 4         4
# ...     ...
# 422031    9
# 422032    9
# 422033    9
# 422034    9
# 422035    9
#
# [422036 rows x 108 columns]

# %%
print(list(base_airbnb.columns))
bronze_path = project_root / "raw" / "base_bronze.csv"
base_airbnb.to_csv(bronze_path, sep=';', index=False)
# Out:
# ['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space', 'description', 'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'street', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market', 'smart_location', 'country_code', 'country', 'latitude', 'longitude', 'is_location_exact', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet', 'price', 'weekly_price', 'monthly_price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm', 'first_review', 'last_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'requires_license', 'license', 'jurisdiction_names', 'instant_bookable', 'is_business_travel_ready', 'cancellation_policy', 'require_guest_profile_picture', 'require_guest_phone_verification', 'calculated_host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month', 'ano', 'mes']

# %%
colunas = ['host_id','host_name','host_response_time','host_response_rate','host_is_superhost','host_listings_count','latitude','longitude','property_type','room_type','accommodates','bathrooms','bedrooms','beds','bed_type','amenities','price','security_deposit','cleaning_fee','guests_included','extra_people','minimum_nights','maximum_nights','number_of_reviews','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value','instant_bookable','is_business_travel_ready','cancellation_policy','ano','mes']

base_airbnb = base_airbnb.loc[:, colunas]
print(list(base_airbnb.columns))
display(base_airbnb)
# Out:
# ['host_id', 'host_name', 'host_response_time', 'host_response_rate', 'host_is_superhost', 'host_listings_count', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price', 'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'instant_bookable', 'is_business_travel_ready', 'cancellation_policy', 'ano', 'mes']
#           host_id                 host_name  host_response_time  \
# 0           68997                  Matthias      within an hour
# 1          102840                   Viviane        within a day
# 2          135635                    Renata      within an hour
# 3          153232                  Patricia  within a few hours
# 4          153691  Patricia Miranda & Paulo      within an hour
# ...           ...                       ...                 ...
# 422031  280625693                   Claudia      within an hour
# 422032   58499305                   Vanessa                 NaN
# 422033    2919803                    Felipe  within a few hours
# 422034    9802173             Jorge Augusto                 NaN
# 422035  263392002                 Jaqueline  a few days or more
#
#        host_response_rate host_is_superhost  host_listings_count  latitude  \
# 0                    100%                 f                  2.0 -22.96592
# 1                     88%                 f                  3.0 -22.97712
# 2                    100%                 t                  1.0 -22.98302
# 3                    100%                 t                  1.0 -22.98816
# 4                    100%                 t                  1.0 -22.98127
# ...                   ...               ...                  ...       ...
# 422031                93%                 f                  0.0 -23.00318
# 422032                NaN                 f                  0.0 -22.96664
# 422033                74%                 f                 32.0 -22.96208
# 422034                NaN                 f                  0.0 -23.00340
# 422035                38%                 f                  5.0 -23.01056
#
#         longitude property_type        room_type  ...  \
# 0       -43.17896   Condominium  Entire home/apt  ...
# 1       -43.19045     Apartment  Entire home/apt  ...
# 2       -43.21427     Apartment  Entire home/apt  ...
# 3       -43.19359     Apartment  Entire home/apt  ...
# 4       -43.19046          Loft  Entire home/apt  ...
# ...           ...           ...              ...  ...
# 422031  -43.34284     Apartment  Entire home/apt  ...
# 422032  -43.39345     Apartment  Entire home/apt  ...
# 422033  -43.17552     Apartment  Entire home/apt  ...
# 422034  -43.34182     Apartment  Entire home/apt  ...
# 422035  -43.36335     Apartment     Private room  ...
#
#         review_scores_cleanliness  review_scores_checkin  \
# 0                            10.0                   10.0
# 1                            10.0                    9.0
# 2                            10.0                   10.0
# 3                             9.0                   10.0
# 4                            10.0                   10.0
# ...                           ...                    ...
# 422031                        NaN                    NaN
# 422032                        NaN                    NaN
# 422033                        NaN                    NaN
# 422034                        NaN                    NaN
# 422035                        NaN                    NaN
#
#         review_scores_communication  review_scores_location  \
# 0                              10.0                    10.0
# 1                              10.0                    10.0
# 2                              10.0                    10.0
# 3                              10.0                    10.0
# 4                              10.0                    10.0
# ...                             ...                     ...
# 422031                          NaN                     NaN
# 422032                          NaN                     NaN
# 422033                          NaN                     NaN
# 422034                          NaN                     NaN
# 422035                          NaN                     NaN
#
#        review_scores_value instant_bookable is_business_travel_ready  \
# 0                      9.0                t                        f
# 1                      9.0                f                        f
# 2                     10.0                t                        f
# 3                     10.0                f                        f
# 4                     10.0                t                        f
# ...                    ...              ...                      ...
# 422031                 NaN                f                        f
# 422032                 NaN                f                        f
# 422033                 NaN                f                        f
# 422034                 NaN                f                        f
# 422035                 NaN                f                        f
#
#                 cancellation_policy   ano  mes
# 0       strict_14_with_grace_period  2019    4
# 1       strict_14_with_grace_period  2019    4
# 2       strict_14_with_grace_period  2019    4
# 3       strict_14_with_grace_period  2019    4
# 4       strict_14_with_grace_period  2019    4
# ...                             ...   ...  ...
# 422031                     flexible  2019    9
# 422032                     flexible  2019    9
# 422033  strict_14_with_grace_period  2019    9
# 422034  strict_14_with_grace_period  2019    9
# 422035  strict_14_with_grace_period  2019    9
#
# [422036 rows x 36 columns]

# %% [markdown]
# # Tratar Valores Faltando
# - Para as colunas que tiverem mais de 300k de valores Null vamos apenas remover elas pois não tem muito o que fazer (levando em conta que temos umabase com 400k de dados)

# %%
for coluna in base_airbnb:
    if base_airbnb[coluna].isnull().sum() > 300000:
        base_airbnb = base_airbnb.drop(coluna, axis=1)
print(base_airbnb.isnull().sum())
# Out:
# host_id                             0
# host_name                         309
# host_response_time             171310
# host_response_rate             171310
# host_is_superhost                 309
# host_listings_count               309
# latitude                            0
# longitude                           0
# property_type                       0
# room_type                           0
# accommodates                        0
# bathrooms                         808
# bedrooms                          324
# beds                              621
# bed_type                            0
# amenities                           0
# price                               0
# security_deposit               191984
# cleaning_fee                   143897
# guests_included                     0
# extra_people                        0
# minimum_nights                      0
# maximum_nights                      0
# number_of_reviews                   0
# review_scores_rating           207234
# review_scores_accuracy         207467
# review_scores_cleanliness      207405
# review_scores_checkin          207486
# review_scores_communication    207395
# review_scores_location         207435
# review_scores_value            207436
# instant_bookable                    0
# is_business_travel_ready            0
# cancellation_policy                 0
# ano                                 0
# mes                                 0
# dtype: int64

# %% [markdown]
# Vamos dropar todos os NaN de nossa base

# %%
base_airbnb = base_airbnb.dropna()

print(base_airbnb.shape)
# Out:
# (115766, 36)

# %% [markdown]
# Demonstrando o tipo de cada coluna com o valor da primeira linha de cada uma.

# %%
print(base_airbnb.dtypes)
print('-'*60)
print(base_airbnb.iloc[0])
# Out:
# host_id                          int64
# host_name                       object
# host_response_time              object
# host_response_rate              object
# host_is_superhost               object
# host_listings_count            float64
# latitude                       float64
# longitude                      float64
# property_type                   object
# room_type                       object
# accommodates                     int64
# bathrooms                      float64
# bedrooms                       float64
# beds                           float64
# bed_type                        object
# amenities                       object
# price                           object
# security_deposit                object
# cleaning_fee                    object
# guests_included                  int64
# extra_people                    object
# minimum_nights                   int64
# maximum_nights                   int64
# number_of_reviews                int64
# review_scores_rating           float64
# review_scores_accuracy         float64
# review_scores_cleanliness      float64
# review_scores_checkin          float64
# review_scores_communication    float64
# review_scores_location         float64
# review_scores_value            float64
# instant_bookable                object
# is_business_travel_ready        object
# cancellation_policy             object
# ano                              int64
# mes                              int64
# dtype: object
# ------------------------------------------------------------
# host_id                                                                    68997
# host_name                                                               Matthias
# host_response_time                                                within an hour
# host_response_rate                                                          100%
# host_is_superhost                                                              f
# host_listings_count                                                          2.0
# latitude                                                               -22.96592
# longitude                                                              -43.17896
# property_type                                                        Condominium
# room_type                                                        Entire home/apt
# accommodates                                                                   5
# bathrooms                                                                    1.0
# bedrooms                                                                     2.0
# beds                                                                         2.0
# bed_type                                                                Real Bed
# amenities                      {TV,"Cable TV",Internet,Wifi,"Air conditioning...
# price                                                                    $302.00
# security_deposit                                                           $0.00
# cleaning_fee                                                             $306.00
# guests_included                                                                2
# extra_people                                                              $58.00
# minimum_nights                                                                 5
# maximum_nights                                                                30
# number_of_reviews                                                            224
# review_scores_rating                                                        93.0
# review_scores_accuracy                                                       9.0
# review_scores_cleanliness                                                   10.0
# review_scores_checkin                                                       10.0
# review_scores_communication                                                 10.0
# review_scores_location                                                      10.0
# review_scores_value                                                          9.0
# instant_bookable                                                               t
# is_business_travel_ready                                                       f
# cancellation_policy                                  strict_14_with_grace_period
# ano                                                                         2019
# mes                                                                            4
# Name: 0, dtype: object

# %%
# host_response_rate (removendo % e convertendo)
base_airbnb['host_response_rate'] = base_airbnb['host_response_rate'].str.replace('%', '')
base_airbnb['host_response_rate'] = base_airbnb['host_response_rate'].astype(np.float32, copy=False)

base_airbnb['host_name'] = (
    base_airbnb['host_name']
    .astype('string')                       
    .str.strip()                            
    .str.title()                            
)

# price
base_airbnb['price'] = base_airbnb['price'].str.replace('$', '')
base_airbnb['price'] = base_airbnb['price'].str.replace(',', '')
base_airbnb['price'] = base_airbnb['price'].astype(np.float32, copy=False)

# extra_people
base_airbnb['extra_people'] = base_airbnb['extra_people'].str.replace('$', '')
base_airbnb['extra_people'] = base_airbnb['extra_people'].str.replace(',', '')
base_airbnb['extra_people'] = base_airbnb['extra_people'].astype(np.float32, copy=False)

# security_deposit
base_airbnb['security_deposit'] = base_airbnb['security_deposit'].str.replace('$', '')
base_airbnb['security_deposit'] = base_airbnb['security_deposit'].str.replace(',', '')
base_airbnb['security_deposit'] = base_airbnb['security_deposit'].astype(np.float32, copy=False)

# cleaning_fee
base_airbnb['cleaning_fee'] = base_airbnb['cleaning_fee'].str.replace('$', '')
base_airbnb['cleaning_fee'] = base_airbnb['cleaning_fee'].str.replace(',', '')
base_airbnb['cleaning_fee'] = base_airbnb['cleaning_fee'].astype(np.float32, copy=False)

# host_is_superhost (t/f → boolean)
base_airbnb['host_is_superhost'] = base_airbnb['host_is_superhost'].map({'t': True, 'f': False}).astype(bool)

# instant_bookable (t/f → boolean)
base_airbnb['instant_bookable'] = base_airbnb['instant_bookable'].map({'t': True, 'f': False}).astype(bool)

# is_business_travel_ready (t/f → boolean)
base_airbnb['is_business_travel_ready'] = base_airbnb['is_business_travel_ready'].map({'t': True, 'f': False}).astype(bool)

# host_response_time, property_type, room_type, bed_type, amenities, cancellation_policy → string
cols_string = [
    'host_response_time', 'property_type', 'room_type',
    'bed_type', 'amenities', 'cancellation_policy'
]
base_airbnb[cols_string] = base_airbnb[cols_string].astype('string')

# latitude e longitude → float32 (reduz espaço)
base_airbnb['latitude'] = base_airbnb['latitude'].astype(np.float32, copy=False)
base_airbnb['longitude'] = base_airbnb['longitude'].astype(np.float32, copy=False)

# verificando os tipos finais
print(base_airbnb.dtypes)
# Out:
# host_id                                 int64
# host_name                      string[python]
# host_response_time             string[python]
# host_response_rate                    float32
# host_is_superhost                        bool
# host_listings_count                   float64
# latitude                              float32
# longitude                             float32
# property_type                  string[python]
# room_type                      string[python]
# accommodates                            int64
# bathrooms                             float64
# bedrooms                              float64
# beds                                  float64
# bed_type                       string[python]
# amenities                      string[python]
# price                                 float32
# security_deposit                      float32
# cleaning_fee                          float32
# guests_included                         int64
# extra_people                          float32
# minimum_nights                          int64
# maximum_nights                          int64
# number_of_reviews                       int64
# review_scores_rating                  float64
# review_scores_accuracy                float64
# review_scores_cleanliness             float64
# review_scores_checkin                 float64
# review_scores_communication           float64
# review_scores_location                float64
# review_scores_value                   float64
# instant_bookable                         bool
# is_business_travel_ready                 bool
# cancellation_policy            string[python]
# ano                                     int64
# mes                                     int64
# dtype: object

# %%
base_numerico = base_airbnb.select_dtypes(include=['float32', 'float64', 'int64', 'int32'])

plt.figure(figsize=(25, 25))
sns.heatmap(base_numerico.corr(), annot=True, cmap='Greens')
plt.title('Matriz de Correlação - Airbnb')
plt.show()

# %% [markdown]
# # Definição de Funções para Análise de Outliers
# Vamos definir algumas funções para ajudar na análise de outliers das colunas

# %%
def limites(coluna):
    q1 = coluna.quantile(0.25)
    q3 = coluna.quantile(0.75)
    amplitude = q3 - q1
    return q1 - 1.5 * amplitude, q3 + 1.5 * amplitude
def excluir_outliers(df, nome_coluna):
    qtde_linhas = df.shape[0]
    lim_inf, lim_sup = limites(df[nome_coluna])
    df = df.loc[(df[nome_coluna] >= lim_inf) & (df[nome_coluna] <= lim_sup), :]
    linhas_removidas = qtde_linhas - df.shape[0]
    return df,  linhas_removidas

# %%
def diagrama_caixa(coluna):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(15, 5)
    sns.boxplot(x=coluna, ax=ax1)
    ax2.set_xlim(limites(coluna))
    sns.boxplot(x=coluna, ax=ax2)
    
def histograma(coluna):
    plt.figure(figsize=(15, 5))
    sns.distplot(coluna, hist=True)

def grafico_barra(coluna):  
    plt.figure(figsize=(15, 5))
    ax = sns.barplot(x=coluna.value_counts().index, y=coluna.value_counts())
    ax.set_xlim(limites(coluna))

# %% [markdown]
# # price

# %%
diagrama_caixa(base_airbnb['price'])
histograma(base_airbnb['price'])
# Out:
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_3840\3668990758.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(coluna, hist=True)

# %% [markdown]
# # removendo outliers de price

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'price')
print('{} linhas removidas'.format(linhas_removidas))
# Out:
# 10287 linhas removidas

# %%
diagrama_caixa(base_airbnb['price'])

# %%
histograma(base_airbnb['price'])
print(base_airbnb.shape)
# Out:
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_3840\3668990758.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(coluna, hist=True)
# (105479, 36)

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'accommodates')
print('{} linhas removidas'.format(linhas_removidas))
# Out:
# 2403 linhas removidas

# %% [markdown]
# # bathrooms

# %%
diagrama_caixa(base_airbnb['bathrooms'])
plt.figure(figsize=(15, 5))
sns.barplot(x=base_airbnb['bathrooms'].value_counts().index, y=base_airbnb['bathrooms'].value_counts())
# Out:
# <Axes: xlabel='bathrooms', ylabel='count'>

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'bathrooms')
print('{} linhas removidas'.format(linhas_removidas))
# Out:
# 746 linhas removidas

# %% [markdown]
# # extra_people

# %%
diagrama_caixa(base_airbnb['extra_people'])
histograma(base_airbnb['extra_people'])
# Out:
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_3840\3668990758.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(coluna, hist=True)

# %%
base_airbnb, linhas_removidas = excluir_outliers(base_airbnb, 'extra_people')
print('{} linhas removidas'.format(linhas_removidas))
# Out:
# 3547 linhas removidas

# %%
diagrama_caixa(base_airbnb['extra_people'])
histograma(base_airbnb['extra_people'])
print(base_airbnb.shape)
# Out:
# C:\Users\Cliente\AppData\Local\Temp\ipykernel_3840\3668990758.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(coluna, hist=True)
# (98783, 36)

# %% [markdown]
# # bedrooms

# %%
diagrama_caixa(base_airbnb['bedrooms'])
grafico_barra(base_airbnb['bedrooms'])

# %% [markdown]
# # beds

# %%
diagrama_caixa(base_airbnb['beds'])
grafico_barra(base_airbnb['beds'])

# %% [markdown]
# # guests_included

# %%
print(limites(base_airbnb['guests_included']))
plt.figure(figsize=(15, 5))
sns.barplot(x=base_airbnb['guests_included'].value_counts().index, y=base_airbnb['guests_included'].value_counts())
# Out:
# (np.float64(-0.5), np.float64(3.5))
# <Axes: xlabel='guests_included', ylabel='count'>

# %% [markdown]
# # minimum_nights

# %%
diagrama_caixa(base_airbnb['minimum_nights'])
grafico_barra(base_airbnb['minimum_nights'])

# %% [markdown]
# # maximum_nights

# %%
diagrama_caixa(base_airbnb['maximum_nights'])
grafico_barra(base_airbnb['maximum_nights'])

# %% [markdown]
# - Essa coluna não parece que vai ajudar na análise.
# - Isso porque parece que quase todos os hosts não preenchem esse campo de maximum nights, então ele não parece que vai ser um fator relevante.
# - É melhor excluirmos essa coluna da análise

# %%
base_airbnb = base_airbnb.drop('maximum_nights', axis=1)
base_airbnb.shape
# Out:
# (98783, 35)

# %% [markdown]
# # number_of_reviews

# %%
diagrama_caixa(base_airbnb['number_of_reviews'])
grafico_barra(base_airbnb['number_of_reviews'])

# %% [markdown]
# # Tratamento de colunas do tipo string

# %% [markdown]
# # Property Type

# %%
print(base_airbnb['property_type'].value_counts())

plt.figure(figsize=(15, 5))
# Out:
# property_type
# Apartment                 77117
# Condominium                6390
# House                      4881
# Serviced apartment         3980
# Loft                       2954
# Guest suite                 636
# Guesthouse                  466
# Aparthotel                  444
# Bed and breakfast           343
# Townhouse                   320
# Hotel                       287
# Hostel                      276
# Boutique hotel              126
# Other                       121
# Villa                       109
# Chalet                       96
# Tiny house                   62
# Cottage                      36
# Earth house                  33
# Bungalow                     31
# Island                       14
# Nature lodge                 14
# Cabin                        12
# Treehouse                    11
# Casa particular (Cuba)        7
# Dome house                    6
# Hut                           4
# Barn                          4
# Igloo                         3
# Name: count, dtype: Int64

# %%
plt.figure(figsize=(10, 8))
grafico = sns.countplot(y='property_type', data=base_airbnb,
                        order=base_airbnb['property_type'].value_counts().index)
grafico.tick_params(axis='y', rotation=0) 
plt.title('Distribuição de Tipos de Propriedade')
plt.xlabel('Quantidade')
plt.ylabel('Tipo de Propriedade')
plt.show()

# %%
tabela_tipos_casa = base_airbnb['property_type'].value_counts()
colunas_agrupar = []

for tipo in tabela_tipos_casa.index:
    if tabela_tipos_casa[tipo] < 2000:
        colunas_agrupar.append(tipo)
print(colunas_agrupar)

for tipo in colunas_agrupar:
    base_airbnb.loc[base_airbnb['property_type']==tipo, 'property_type'] = 'Outros'

print(base_airbnb['property_type'].value_counts())
# Out:
# ['Guest suite', 'Guesthouse', 'Aparthotel', 'Bed and breakfast', 'Townhouse', 'Hotel', 'Hostel', 'Boutique hotel', 'Other', 'Villa', 'Chalet', 'Tiny house', 'Cottage', 'Earth house', 'Bungalow', 'Island', 'Nature lodge', 'Cabin', 'Treehouse', 'Casa particular (Cuba)', 'Dome house', 'Hut', 'Barn', 'Igloo']
# property_type
# Apartment             77117
# Condominium            6390
# House                  4881
# Serviced apartment     3980
# Outros                 3461
# Loft                   2954
# Name: count, dtype: Int64

# %%
plt.figure(figsize=(15, 5))
grafico = sns.countplot(y='property_type', data=base_airbnb)
grafico.tick_params(axis='y', rotation=0)  # não precisa rotacionar os labels
plt.title('Distribuição de Tipos de Propriedade')
plt.xlabel('Quantidade')
plt.ylabel('Tipo de Propriedade')
plt.show()

# %% [markdown]
# # Room type

# %%
print(base_airbnb['room_type'].value_counts())

plt.figure(figsize=(15, 5))
grafico = sns.countplot(
    y='room_type',
    data=base_airbnb,
    order=base_airbnb['room_type'].value_counts().index
)
grafico.tick_params(axis='y', rotation=0)
plt.title('Distribuição de Tipos de Quarto (Transposto)')
plt.xlabel('Quantidade')
plt.ylabel('Tipo de Quarto')
plt.show()
# Out:
# room_type
# Entire home/apt    75774
# Private room       21254
# Shared room         1142
# Hotel room           613
# Name: count, dtype: Int64

# %% [markdown]
# # Bed type

# %%
print(base_airbnb['bed_type'].value_counts())


plt.figure(figsize=(15, 5))
grafico = sns.countplot(x='bed_type', data=base_airbnb)
grafico.tick_params(axis='x', rotation=90)
plt.title('Distribuição original - bed_type')
plt.show()

tabela_bed = base_airbnb['bed_type'].value_counts()
colunas_agrupar = tabela_bed[tabela_bed < 10000].index.tolist()

for tipo in colunas_agrupar:
    base_airbnb.loc[base_airbnb['bed_type'] == tipo, 'bed_type'] = 'Outros'

print(base_airbnb['bed_type'].value_counts())

plt.figure(figsize=(15, 5))
grafico = sns.countplot(y='bed_type', data=base_airbnb,
                        order=base_airbnb['bed_type'].value_counts().index)
grafico.tick_params(axis='y', rotation=0)
plt.title('Distribuição agrupada - bed_type')
plt.xlabel('Quantidade')
plt.ylabel('Tipo de Cama')
plt.show()
# Out:
# bed_type
# Real Bed         97508
# Pull-out Sofa      939
# Futon              246
# Couch               73
# Airbed              17
# Name: count, dtype: Int64
# bed_type
# Real Bed    97508
# Outros       1275
# Name: count, dtype: Int64

# %% [markdown]
# # Cancellation policy

# %%
print(base_airbnb['cancellation_policy'].value_counts())

plt.figure(figsize=(15, 5))
grafico = sns.countplot(y='cancellation_policy', data=base_airbnb)
grafico.tick_params(axis='y', rotation=0)
plt.title('Distribuição original - cancellation_policy')
plt.show()

tabela_cancellation = base_airbnb['cancellation_policy'].value_counts()
colunas_agrupar = []

for tipo in tabela_cancellation.index:
    if tabela_cancellation[tipo] < 10000:
        colunas_agrupar.append(tipo)
print(colunas_agrupar)

for tipo in colunas_agrupar:
    base_airbnb.loc[base_airbnb['cancellation_policy'] == tipo, 'cancellation_policy'] = 'strict'

print(base_airbnb['cancellation_policy'].value_counts())
plt.figure(figsize=(15, 5))
grafico = sns.countplot(y='cancellation_policy', data=base_airbnb,
                        order=base_airbnb['cancellation_policy'].value_counts().index)
grafico.tick_params(axis='y', rotation=0)
plt.title('Distribuição agrupada - cancellation_policy (Transposto)')
plt.xlabel('Quantidade')
plt.ylabel('Cancellation Policy')
plt.show()
# Out:
# cancellation_policy
# strict_14_with_grace_period    53206
# moderate                       23414
# flexible                       19657
# super_strict_60                 1663
# super_strict_30                  831
# strict                            12
# Name: count, dtype: Int64
# ['super_strict_60', 'super_strict_30', 'strict']
# cancellation_policy
# strict_14_with_grace_period    53206
# moderate                       23414
# flexible                       19657
# strict                          2506
# Name: count, dtype: Int64

# %% [markdown]
# # Amenities

# %%
print(base_airbnb['amenities'].iloc[1].split(','))
print(len(base_airbnb['amenities'].iloc[1].split(',')))

base_airbnb['n_amenities'] = base_airbnb['amenities'].str.split(',').apply(len)
# Out:
# ['{TV', '"Cable TV"', 'Internet', 'Wifi', '"Air conditioning"', 'Kitchen', 'Doorman', 'Elevator', '"Buzzer/wireless intercom"', '"Family/kid friendly"', 'Hangers', '"Hair dryer"', 'Iron', '"Laptop friendly workspace"}']
# 14

# %%
base_airbnb = base_airbnb.drop('amenities', axis=1)
base_airbnb.shape
# Out:
# (98783, 35)

# %%
diagrama_caixa(base_airbnb['n_amenities'])
grafico_barra(base_airbnb['n_amenities'])

# %%
amostra = base_airbnb.sample(n=90000)
centro_mapa = {'lat': amostra.latitude.mean(), 'lon': amostra.longitude.mean()}

mapa = px.density_map(
    amostra,
    lat='latitude',
    lon='longitude',
    z='price',
    radius=2.5,
    center=centro_mapa,
    zoom=10,
    map_style='open-street-map'
)

mapa.show()

# %% [markdown]
# # Gerando base Prata

# %%
project_root = pathlib.Path(os.getcwd()).resolve().parents[0]
silver_path = project_root / "silver"
silver_path.mkdir(parents=True, exist_ok=True)


silver_file = silver_path / "base_de_dados_prata.csv"
base_airbnb.to_csv(silver_file, index=False)

# %%
base_airbnb.dtypes
# Out:
# host_id                                 int64
# host_name                      string[python]
# host_response_time             string[python]
# host_response_rate                    float32
# host_is_superhost                        bool
# host_listings_count                   float64
# latitude                              float32
# longitude                             float32
# property_type                  string[python]
# room_type                      string[python]
# accommodates                            int64
# bathrooms                             float64
# bedrooms                              float64
# beds                                  float64
# bed_type                       string[python]
# price                                 float32
# security_deposit                      float32
# cleaning_fee                          float32
# guests_included                         int64
# extra_people                          float32
# minimum_nights                          int64
# number_of_reviews                       int64
# review_scores_rating                  float64
# review_scores_accuracy                float64
# review_scores_cleanliness             float64
# review_scores_checkin                 float64
# review_scores_communication           float64
# review_scores_location                float64
# review_scores_value                   float64
# instant_bookable                         bool
# is_business_travel_ready                 bool
# cancellation_policy            string[python]
# ano                                     int64
# mes                                     int64
# n_amenities                             int64
# dtype: object

# %%
base_airbnb.head()
# Out:
#    host_id                 host_name  host_response_time  host_response_rate  \
# 0    68997                  Matthias      within an hour               100.0
# 1   102840                   Viviane        within a day                88.0
# 2   135635                    Renata      within an hour               100.0
# 3   153232                  Patricia  within a few hours               100.0
# 4   153691  Patricia Miranda & Paulo      within an hour               100.0
#
#    host_is_superhost  host_listings_count   latitude  longitude property_type  \
# 0              False                  2.0 -22.965919 -43.178959   Condominium
# 1              False                  3.0 -22.977119 -43.190449     Apartment
# 2               True                  1.0 -22.983021 -43.214272     Apartment
# 3               True                  1.0 -22.988159 -43.193588     Apartment
# 4               True                  1.0 -22.981270 -43.190460          Loft
#
#          room_type  ...  review_scores_checkin  review_scores_communication  \
# 0  Entire home/apt  ...                   10.0                         10.0
# 1  Entire home/apt  ...                    9.0                         10.0
# 2  Entire home/apt  ...                   10.0                         10.0
# 3  Entire home/apt  ...                   10.0                         10.0
# 4  Entire home/apt  ...                   10.0                         10.0
#
#    review_scores_location  review_scores_value instant_bookable  \
# 0                    10.0                  9.0             True
# 1                    10.0                  9.0            False
# 2                    10.0                 10.0             True
# 3                    10.0                 10.0            False
# 4                    10.0                 10.0             True
#
#    is_business_travel_ready          cancellation_policy   ano  mes  \
# 0                     False  strict_14_with_grace_period  2019    4
# 1                     False  strict_14_with_grace_period  2019    4
# 2                     False  strict_14_with_grace_period  2019    4
# 3                     False  strict_14_with_grace_period  2019    4
# 4                     False  strict_14_with_grace_period  2019    4
#
#    n_amenities
# 0           25
# 1           14
# 2           17
# 3           31
# 4           35
#
# [5 rows x 35 columns]

# %% [markdown]
# # Jogando dentro do nosso banco de dados postgres do docker

# %%
engine = create_engine("postgresql://postgres:postgres@localhost:5432/airbnb")

# %%
csv_path = "../silver/base_de_dados_prata.csv"
df_silver = pd.read_csv(csv_path, sep=",", low_memory=False)
df_silver.head()
# Out:
#    host_id                 host_name  host_response_time  host_response_rate  \
# 0    68997                  Matthias      within an hour               100.0
# 1   102840                   Viviane        within a day                88.0
# 2   135635                    Renata      within an hour               100.0
# 3   153232                  Patricia  within a few hours               100.0
# 4   153691  Patricia Miranda & Paulo      within an hour               100.0
#
#    host_is_superhost  host_listings_count  latitude  longitude property_type  \
# 0              False                  2.0 -22.96592  -43.17896   Condominium
# 1              False                  3.0 -22.97712  -43.19045     Apartment
# 2               True                  1.0 -22.98302  -43.21427     Apartment
# 3               True                  1.0 -22.98816  -43.19359     Apartment
# 4               True                  1.0 -22.98127  -43.19046          Loft
#
#          room_type  ...  review_scores_checkin  review_scores_communication  \
# 0  Entire home/apt  ...                   10.0                         10.0
# 1  Entire home/apt  ...                    9.0                         10.0
# 2  Entire home/apt  ...                   10.0                         10.0
# 3  Entire home/apt  ...                   10.0                         10.0
# 4  Entire home/apt  ...                   10.0                         10.0
#
#    review_scores_location  review_scores_value instant_bookable  \
# 0                    10.0                  9.0             True
# 1                    10.0                  9.0            False
# 2                    10.0                 10.0             True
# 3                    10.0                 10.0            False
# 4                    10.0                 10.0             True
#
#    is_business_travel_ready          cancellation_policy   ano  mes  \
# 0                     False  strict_14_with_grace_period  2019    4
# 1                     False  strict_14_with_grace_period  2019    4
# 2                     False  strict_14_with_grace_period  2019    4
# 3                     False  strict_14_with_grace_period  2019    4
# 4                     False  strict_14_with_grace_period  2019    4
#
#    n_amenities
# 0           25
# 1           14
# 2           17
# 3           31
# 4           35
#
# [5 rows x 35 columns]

# %%
with engine.connect() as conn:
    conn.execute(text("CREATE SCHEMA IF NOT EXISTS silver;"))
    conn.commit()

# %%
df_silver.to_sql(
    name="airbnb_2019",
    schema="silver",
    con=engine,
    if_exists="replace",
    index=False
)
# Out:
# 713

# %%
pd.read_sql("SELECT COUNT(*) FROM silver.airbnb_2019;", engine)
# Out:
#    count
# 0  98783
